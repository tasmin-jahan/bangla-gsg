# %% [markdown]
# # Translation Evaluation
# This notebook runs the translation evaluation script and displays the results.

# %%
# Run the evaluation script for English to Bangla (Zero-shot or Few-shot)
# !python ../src/eval/run_translation_eval.py --model_path ../saved/checkpoints/step_00036714.pt --data_path /home/farhan/my-projects/bangla-gamba/saved/data/raw/opus_opensubtitles.jsonl --direction en_bn --num_samples 100 --few_shot 3

# %%
# Run the evaluation script for Bangla to English
# !python ../src/eval/run_translation_eval.py --model_path ../saved/checkpoints/step_00036714.pt --data_path /home/farhan/my-projects/bangla-gamba/saved/data/raw/opus_opensubtitles.jsonl --direction bn_en --num_samples 100 --few_shot 3

# %%
import pandas as pd

# Display the results
results_path = "../saved/logs/translation_eval_results.csv"
try:
    df = pd.read_csv(results_path)
    display(df)
except FileNotFoundError:
    print("Results file not found. Run the evaluation scripts above first.")
